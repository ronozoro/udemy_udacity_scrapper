# %% [markdown]
# # Setup Enviroment

# %%
import pandas as pd
import numpy as np
import pymongo
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import r2_score

# %% [markdown]
# ##### Mongo Connection Details

# %%
MONGODB_SERVER = "localhost"
MONGODB_PORT = 27017
MONGODB_DB = "courses"

# %% [markdown]
# ##### Load Mongo Collections for udemy and udacity to merge
#
# prepare to clean and insert the data into the cleaned collection

# %%
mongo_client = pymongo.MongoClient('mongodb://localhost:27017')
db = mongo_client.courses

# %%
cleaned_courses_col=db.cleaned_courses
cleaned_courses_col.drop()
cleaned_courses=[]

# %%
udacity_courses=db.udacity_courses
udemy_courses=db.udemy_courses

# %% [markdown]
# ##### get cleaned udacity courses

# %%
for udacity_course in udacity_courses.find():
    data = {
        "title": udacity_course['name'],
        "url": udacity_course['url'],
        "description": udacity_course['about'],
        "syllabus": 'Not Avilable',
        "skills": udacity_course['skills'],
        "ratings_count": udacity_course['num_reviews'],
        "prerequisites": udacity_course['prerequisites'],
        "duration": udacity_course['duration'],
        "category": udacity_course['category'],
        "level": udacity_course['level'],
        "schoolName": udacity_course['school_name'],
        "instructors": udacity_course['instructors'],
        "enrolled_students_count": 0,
        "avg_rating": udacity_course['avg_rating'],
        "num_reviews": udacity_course['num_reviews'],
        "price": udacity_course['price'],
        "source": 'Udacity'
    }
    cleaned_courses_col.insert_one(data)

# %% [markdown]
# ##### get cleaned udemy courses

# %%
import html2text
for udemy_course in udemy_courses.find():
    description=udemy_course['description']
    converter = html2text.HTML2Text()
    converter.ignore_links = True
    data = {
        "title": udemy_course['title'],
        "url": udemy_course['url'],
        "description": converter.handle(description)[76:],
        "syllabus": udemy_course['objectives'],
        "skills": udemy_course['title'],
        "ratings_count": udemy_course['num_reviews'],
        "prerequisites": udemy_course['prerequisites'],
        "duration": 'Not Available',
        "category": 'Course',
        "level": udemy_course['instructional_level_simple'],
        "schoolName": 'Provided by Udemy Instructors',
        "instructors": [item['display_name'] for item in udemy_course['visible_instructors']],
        "enrolled_students_count": udemy_course['num_subscribers'],
        "avg_rating": udemy_course['avg_rating'],
        "num_reviews": udemy_course['num_reviews'],
        "price": udemy_course['price'],
        "source": 'Udemy'
    }
    cleaned_courses_col.insert_one(data)

# %%
def _connect_mongo(host, port, username, password, db):
    if username and password:
        mongo_uri = 'mongodb://%s:%s@%s:%s/%s' % (username, password, host, port, db)
        conn = pymongo.MongoClient(mongo_uri)
    else:
        conn = pymongo.MongoClient(host, port)
    return conn[db]

# %%
def read_mongo(db, collection, query={}, host='localhost', port=27017, username=None, password=None, no_id=True):
    db = _connect_mongo(host=host, port=port, username=username, password=password, db=db)
    cursor = db[collection].find(query)
    df =  pd.DataFrame(list(cursor))
    if no_id:
        del df['_id']
    return df

# %%
df_clean_courses=read_mongo('courses','cleaned_courses')

# %%
df_clean_courses.sample(10)
# Out:
#                                                   title  \
# 2144  Trade with just 11 Candlesticks signals – Reap...
# 9052      ADSENSE ARBITRAGE:  ADSENSE TRAFFIC ARBITRAGE
# 9906  Create Winning Online Marketing Campaigns In M...
# 2710  Affiliate Marketing Secrets Set Up a Business ...
# 4451  Humanoid Rigging For Games Using Houdini And K...
# 5670  Educational Psychology & Special Education (Ce...
# 2888           MSP® Programme Management - Introduction
# 5917  Quran Level 1 - Qaida Nuraniyah - Child Boy Ed...
# 6558  Presentation Skills: Master Confident Presenta...
# 7621        ICS/SCADA Network Security Monitoring (NSM)
#
#                                                     url  \
# 2144  https://www.udemy.com/course/trade-with-just-1...
# 9052  https://www.udemy.com/course/adsense-traffic-a...
# 9906  https://www.udemy.com/course/create-winning-on...
# 2710  https://www.udemy.com/course/clickbank-affilia...
# 4451  https://www.udemy.com/course/humanoid-rigging-...
# 5670  https://www.udemy.com/course/educational-psych...
# 2888  https://www.udemy.com/course/msp-programme-man...
# 5917  https://www.udemy.com/course/nuraniyahboyedition/
# 6558  https://www.udemy.com/course/presentations-mas...
# 7621  https://www.udemy.com/course/icsscada-network-...
#
#                                             description  \
# 2144  you often regret selling and buying stocks as ...
# 9052  \nto make money online. You don't have to make...
# 9906  es, automatically optimized over the entire ca...
# 2710  ion  \n\n“ _ **Clickbank: Affiliate Marketing ...
# 4451  e\ncompatible with game engines like Unity and...
# 5670  gnitive, emotional, and social\nleaning proces...
# 2888  thod called MSP® Programme Management, a best ...
# 5917  \nis the:**\n\n  *  ** _EASIEST_ and the _FAST...
# 6558  dent public speaker - overcome nerves and deli...
# 7621  t\nmonitor and control industrial processes. T...
#
#                                                syllabus  \
# 2144  [•\tLearn how to identify a big trend reversal...
# 9052  [you can make a extra or full time earnings wi...
# 9906  [online marketing, digital markeiting, Online ...
# 2710  [Pick the most profitable niche., Setting up a...
# 4451  [We will create a basic humanoid rig in houdini.]
# 5670  [This course focuses on teaching educational p...
# 2888  [Understand the key principles and terminology...
# 5917  [The child will be able to make a smooth trans...
# 6558  [Be a memorable and confident speaker, Give a ...
# 7621  [They will learn how to apply open source tool...
#
#                                                  skills  ratings_count  \
# 2144  Trade with just 11 Candlesticks signals – Reap...              9
# 9052      ADSENSE ARBITRAGE:  ADSENSE TRAFFIC ARBITRAGE            199
# 9906  Create Winning Online Marketing Campaigns In M...             53
# 2710  Affiliate Marketing Secrets Set Up a Business ...            202
# 4451  Humanoid Rigging For Games Using Houdini And K...             15
# 5670  Educational Psychology & Special Education (Ce...            410
# 2888           MSP® Programme Management - Introduction              3
# 5917  Quran Level 1 - Qaida Nuraniyah - Child Boy Ed...              8
# 6558  Presentation Skills: Master Confident Presenta...           7074
# 7621        ICS/SCADA Network Security Monitoring (NSM)            139
#
#                                           prerequisites       duration  \
# 2144  [•\tEveryone is welcome, •\tYou must have the ...  Not Available
# 9052  [Adsense Account, Wordpress Website, 5$ For Fa...  Not Available
# 9906     [No special requirements or experience needed]  Not Available
# 2710  [You need to have internet connection,  Absolu...  Not Available
# 4451  [Students will need a basic understanding of t...  Not Available
# 5670                                              [n/a]  Not Available
# 2888  [Familiarity with projects, programmes and Pro...  Not Available
# 5917   [No prior knowledge of Arabic language required]  Not Available
# 6558  [Nothing - just a willingness to learn!, A tal...  Not Available
# 7621  [It would be beneficial if you took my first c...  Not Available
#
#      category         level                     schoolName  \
# 2144   Course    All Levels  Provided by Udemy Instructors
# 9052   Course    All Levels  Provided by Udemy Instructors
# 9906   Course    All Levels  Provided by Udemy Instructors
# 2710   Course    All Levels  Provided by Udemy Instructors
# 4451   Course  Intermediate  Provided by Udemy Instructors
# 5670   Course    All Levels  Provided by Udemy Instructors
# 2888   Course      Beginner  Provided by Udemy Instructors
# 5917   Course      Beginner  Provided by Udemy Instructors
# 6558   Course    All Levels  Provided by Udemy Instructors
# 7621   Course  Intermediate  Provided by Udemy Instructors
#
#                   instructors  enrolled_students_count  avg_rating  \
# 2144             [Dr Bishram]                       13    4.666666
# 9052              [Raj Kumar]                     1002    4.200000
# 9906            [Andre Bolte]                     6705    4.500000
# 2710           [Scrembo Paul]                    12203    3.400000
# 4451            [Simon Hayes]                      103    4.566667
# 5670           [Dr. Bev Knox]                     1416    4.449153
# 2888  [Stone River eLearning]                       11    4.000000
# 5917             [Hamid Raza]                       39    4.750000
# 6558            [Chris Croft]                    19000    4.524620
# 7621             [Ed Galarza]                      771    4.000000
#
#       num_reviews   price source
# 2144            9  $89.99  Udemy
# 9052          199  $24.99  Udemy
# 9906           53  $19.99  Udemy
# 2710          202  $19.99  Udemy
# 4451           15  $44.99  Udemy
# 5670          410  $89.99  Udemy
# 2888            3  $89.99  Udemy
# 5917            8  $39.99  Udemy
# 6558         7074  $89.99  Udemy
# 7621          139  $89.99  Udemy

# %% [markdown]
# ##### Convert all prices to egp

# %%
def clean_price_egp(x):
    return float(x.replace('$',''))*16

# %%
df_clean_courses.loc[df_clean_courses['source']=='Udemy', ['price']] = df_clean_courses[df_clean_courses['source']=='Udemy']['price'].apply(lambda x : clean_price_egp(x))

# %% [markdown]
# ##### Take a look into categories and levels

# %%
df_clean_courses['category'].value_counts()
# Out:
# Course        10186
# nanodegree      102
# Name: category, dtype: int64

# %%
df_clean_courses['level'].value_counts()
# Out:
# All Levels      5371
# Beginner        3137
# Intermediate    1282
# Expert           217
# intermediate     161
# beginner          71
# advanced          46
#                    1
# Name: level, dtype: int64

# %%
df_clean_courses['source'].value_counts()
# Out:
# Udemy      10008
# Udacity      276
# Name: source, dtype: int64

# %% [markdown]
# ##### Fixing levels as there is duplicates

# %%
df_clean_courses.loc[df_clean_courses['level']=='Beginner', ['level']]='beginner'
df_clean_courses.loc[df_clean_courses['level']=='Intermediate', ['level']]='intermediate'
df_clean_courses.loc[df_clean_courses['level']=='advanced', ['level']]='Expert'

# %%
df_clean_courses['level'].value_counts()
# Out:
# All Levels      5371
# beginner        3208
# intermediate    1443
# Expert           263
#                    1
# Name: level, dtype: int64

# %%
df_clean_courses['schoolName'].value_counts()
# Out:
# Provided by Udemy Instructors          10008
# School of Programming & Development      139
# School of Artificial Intelligence         45
# School of Data Science                    25
# School of Business                        18
# School of Product Management              15
# Career Advancement                        11
# School of Autonomous Systems              10
# School of Cloud Computing                  9
# School of Cybersecurity                    4
# Name: schoolName, dtype: int64

# %%
df_clean_courses['duration'].value_counts()
# Out:
# Not Available    10008
# 4 Months            39
# 2 Months            39
# 3 Months            31
# 2 Weeks             28
# 3 Weeks             21
# 1 Week              18
# 1 Month             16
# 4 Weeks             12
# 16 Weeks             8
# 2 Days               7
# 6 Weeks              6
# 20 Hours             6
# 1 Day                5
# 5 Weeks              5
# 8 Weeks              5
#                      4
# 6 Months             3
# 5 Months             3
# 7 Days               2
# 35 Hours             2
# 7 Weeks              2
# 21 Hours             2
# 10 Weeks             1
# 3 Days               1
# 28 Hours             1
# 160 Hours            1
# 6 Days               1
# 16 Hours             1
# 15 Hours             1
# 25 Hours             1
# 17 Hours             1
# 60 Hours             1
# 10 Hours             1
# 1 Hour               1
# Name: duration, dtype: int64

# %% [markdown]
# ##### remove na data from the dataset

# %%
df_clean_courses.dropna(inplace=True)

# %% [markdown]
# ##### encode categorical values in the dataset

# %%
labelencoder = LabelEncoder()
df_clean_courses['level'] = labelencoder.fit_transform(df_clean_courses['level'])
df_clean_courses['schoolName'] = labelencoder.fit_transform(df_clean_courses['schoolName'])
df_clean_courses['category'] = labelencoder.fit_transform(df_clean_courses['category'])
df_clean_courses['source'] = labelencoder.fit_transform(df_clean_courses['source'])

# %%
df_clean_courses
# Out:
#                                                    title  \
# 0                                         Data Architect
# 1                            Natural Language Processing
# 2                                     AI Product Manager
# 3                             Intro to Self-Driving Cars
# 4                          Introduction to Cybersecurity
# ...                                                  ...
# 10283  Complete RPG Maker MZ: Create and Publish for ...
# 10284      Create Your Empowering Feng Shui Vision Board
# 10285                   CCNP ENTEPRRISE - ENARSI-300-410
# 10286                      CSS3 Transition and Animation
# 10287  Complete C# programming Fundamentals With Exam...
#
#                                                      url  \
# 0      https://www.udacity.com/course/data-architect-...
# 1      https://www.udacity.com/course/natural-languag...
# 2      https://www.udacity.com/course/ai-product-mana...
# 3      https://www.udacity.com/course/intro-to-self-d...
# 4      https://www.udacity.com/course/intro-to-cybers...
# ...                                                  ...
# 10283  https://www.udemy.com/course/complete-rpg-make...
# 10284  https://www.udemy.com/course/feng-shui-vision-...
# 10285          https://www.udemy.com/course/ccnp-enarsi/
# 10286  https://www.udemy.com/course/css3-transition-a...
# 10287  https://www.udemy.com/course/complete-c-sharp-...
#
#                                              description  \
# 0      Learn how to plan, design and implement enterp...
# 1      Learn the skills to get computers to understan...
# 2      Learn to develop AI products that deliver busi...
# 3      This introductory program is the perfect way t...
# 4      Get your start in the high growth field of cyb...
# ...                                                  ...
# 10283  e teach you how to use the power of RPG Maker\...
# 10284  Are you searching for purpose in life? Are you...
# 10285  0\ngives you the knowledge you need to install...
# 10286   Keyframes\n\n  * Animation\n\n  * Animation I...
# 10287  om\nthe very beginning by teaching you C# prog...
#
#                                                 syllabus  \
# 0                                           Not Avilable
# 1                                           Not Avilable
# 2                                           Not Avilable
# 3                                           Not Avilable
# 4                                           Not Avilable
# ...                                                  ...
# 10283  [Learn everything about RPG Maker MZ from begi...
# 10284  [Basics of Feng Shui: Understanding it's meani...
# 10285  [Implement, Optimizing ,Troubleshooting EIGRP,...
# 10286  [Keyframes, Animation, Animation Iteration, An...
# 10287  [Master the fundamentals of C# programming fro...
#
#                                                   skills  ratings_count  \
# 0      Entity relationship diagrams, Relational Data ...             68
# 1      Machine Learning,Speech Recognition,Sentiment ...            470
# 2      AI Products,Training ML Models,Annotating Data...            513
# 3      Computer Vision,Machine Learning,Vehicle Motio...            743
# 4      Threat Assessment,Security Vulnerabilities,Com...             96
# ...                                                  ...            ...
# 10283  Complete RPG Maker MZ: Create and Publish for ...             11
# 10284      Create Your Empowering Feng Shui Vision Board              1
# 10285                   CCNP ENTEPRRISE - ENARSI-300-410             47
# 10286                      CSS3 Transition and Animation              0
# 10287  Complete C# programming Fundamentals With Exam...             38
#
#                                            prerequisites       duration  \
# 0      Intermediate Python, SQL, and Basics of ETL/Da...       4 Months
# 1      Python, Statistics, Machine Learning, & Deep L...       3 Months
# 2                                 No Experience Required       2 Months
# 3                              Programming & Mathematics       4 Months
# 4      Basic knowledge of network connectivity and OS...       4 Months
# ...                                                  ...            ...
# 10283  [RPG Maker MZ software that costs $80 on Steam...  Not Available
# 10284  [No experience needed. Interest in spiritualit...  Not Available
# 10285  [General understanding of network fundamentals...  Not Available
# 10286  [This is a beginner to advance course — You do...  Not Available
# 10287  [No basic knowledge of computer programming is...  Not Available
#
#        category  level  schoolName  \
# 0             1      2           7
# 1             1      2           2
# 2             1      3           8
# 3             1      4           3
# 4             1      3           6
# ...         ...    ...         ...
# 10283         0      3           1
# 10284         0      1           1
# 10285         0      4           1
# 10286         0      1           1
# 10287         0      1           1
#
#                                              instructors  \
# 0      [Ben Larson, Shankar Korrapolu, Shrinath Parik...
# 1      [Luis Serrano, Jay Alammar, Arpan Chakraborty,...
# 2      [Alyssa Simpson-Rochwerger, Meeta Dash, Kiran ...
# 3      [Sebastian Thrun, Andy Brown, Cezanne Camacho,...
# 4      [Ron Woerner, CISSP, CISM, Jerry Smith, Christ...
# ...                                                  ...
# 10283                                  [Andres Cavallin]
# 10284                            [Patricia "Trish" John]
# 10285                                   [sikandar Shaik]
# 10286                         [MD TAFSIRUL HAQUE DANISH]
# 10287                   [Emenwa Global, Zoolord Academy]
#
#        enrolled_students_count  avg_rating  num_reviews    price  source
# 0                            0    4.400000           68    21696       0
# 1                            0    4.520000          470    16272       0
# 2                            0    4.340000          513    10848       0
# 3                            0    4.650000          743    21696       0
# 4                            0    4.490000           96    21696       0
# ...                        ...         ...          ...      ...     ...
# 10283                      105    4.681818           11   959.84       1
# 10284                        8    4.000000            1   879.84       1
# 10285                      284    4.388889           47   479.84       1
# 10286                        0    0.000000            0   319.84       1
# 10287                     8878    4.300000           38  1439.84       1
#
# [10284 rows x 17 columns]

# %%
train_df, val_df = train_test_split(df_clean_courses, test_size=0.3, random_state=42)

X_train = train_df[['ratings_count','category','level','schoolName','enrolled_students_count','avg_rating','num_reviews','source']]
y_train = train_df['price']

X_val = val_df[['ratings_count','category','level','schoolName','enrolled_students_count','avg_rating','num_reviews','source']]
y_val = val_df['price']

# %%
regressor = RandomForestRegressor(max_depth=2,random_state=0)
regressor = regressor.fit(X_train, y_train)

# %%
y_pred1=regressor.predict(X_train)

# %%
r2_score(y_train, y_pred1)
# Out:
# 0.7970385095890317

# %%
y_pred2=regressor.predict(X_val)

# %%
y_pred2
# Out:
# array([1025.12266898,  757.04136668, 1015.84489947, ...,  780.62856816,
#        1025.12266898,  872.65870201])

# %%
r2_score(y_val, y_pred2)
# Out:
# 0.8253549052052905
